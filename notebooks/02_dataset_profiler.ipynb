# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.data_loader import load_dataset
from src.profiler import DatasetProfiler

# %%
df = load_dataset("../data/raw/titanic.csv")

profiler = DatasetProfiler(df)

# %%
profiler.rows()
# Out:
# 891

# %%
profiler.columns()
# Out:
# 12

# %%
profiler.numeric_columns()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
profiler.categorical_columns()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
profiler.missing_values()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
profiler.memory_usage()
# Out:
# np.float64(118.89)

# %%
profiler.quality_report()
# Out:
# {'Score': np.float64(95.95),
#  'Grade': 'Excellent',
#  'Missing (%)': np.float64(8.1),
#  'Duplicate (%)': np.float64(0.0)}
