# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.data_loader import load_dataset
from src.visualizer import DataVisualizer

# %%
df = load_dataset("../data/raw/titanic.csv")

viz = DataVisualizer(df)

# %%
fig = viz.histogram("Age")

fig.show()

# %%
fig = viz.boxplot("Fare")

fig.show()

# %%
viz.scatter_plot("Age", "Fare").show()

# %%
viz.line_plot("Age", "Fare").show()

# %%
viz.bar_chart("Survived").show()

# %%
viz.pie_chart("Sex").show()

# %%
viz.correlation_heatmap().show()

# %%
viz.missing_values_chart().show()

# %%
viz.violin_plot("Age").show()

# %%
viz.distribution_plot("Fare").show()
